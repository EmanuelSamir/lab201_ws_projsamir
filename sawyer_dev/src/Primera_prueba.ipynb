# %% [markdown]
# # Prueba para joint 7 con movimiento sinusoidal
# ## Coding
# ### Importando librerías

# %%
#importing all libraries
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import numpy as np

# %% [markdown]
# ### Muestra de data para una ventana de 3000 datos

# %%
df = pd.read_csv('training_data_joint1.csv')
fig1 = plt.figure()
df.j7[0:3000].plot()
df.jd7[0:3000].plot(); plt.legend(loc='best')
fig2 = plt.figure(); df.e7[0:1000].plot(); plt.legend(loc='best')
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-3-57b614e10c64> in <module>()
#       1
# ----> 2 df = pd.read_csv('training_data_joint7.csv')
#       3 fig1 = plt.figure()
#       4 df.j7[0:3000].plot()
#       5 df.jd7[0:3000].plot(); plt.legend(loc='best')
#
# ...

# %% [markdown]
# ### Muestra de delta de rad

# %%
delta_j7 = df.j7 - df.jd7
fig3 = plt.figure(); delta_j7.plot(); plt.legend(loc='best')

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten

# %%
model = Sequential()
model.add(Dense(units=10, activation='linear', input_dim=2))
model.add(Dense(units=10, activation='linear'))
model.add(Dense(units=1, activation='linear'))

model.compile(loss='mean_squared_error',
              optimizer='sgd',
              metrics=['accuracy'])

# %%
q_data = df.j7.values.reshape(20001,1)
T_data = df.e7.values.reshape(20001,1)
qd_data = df.jd7
x_train = np.concatenate([q_data, T_data], axis =1)
y_train = qd_data.values.reshape(20001,1)
print x_train.shape
print y_train.shape

#x_train = df['j7', 'e7']
#y_train = df['jd7
# Out:
# (20001, 2)
# (20001, 1)

# %%
model.fit(x_train, y_train, epochs=100, batch_size=50)
# Out:
# Epoch 1/100
# 20001/20001 [==============================] - 1s 58us/step - loss: 0.0080 - acc: 4.9997e-05
# Epoch 2/100
# 20001/20001 [==============================] - 1s 51us/step - loss: 0.0034 - acc: 4.9997e-05
# Epoch 3/100
# 20001/20001 [==============================] - 1s 48us/step - loss: 0.0018 - acc: 4.9997e-05
# Epoch 4/100
# 20001/20001 [==============================] - 1s 48us/step - loss: 0.0011 - acc: 4.9997e-05
# Epoch 5/100
# 20001/20001 [==============================] - 1s 50us/step - loss: 8.0444e-04 - acc: 4.9997e-05
# Epoch 6/100
# 20001/20001 [==============================] - 1s 46us/step - loss: 7.0101e-04 - acc: 4.9997e-05
# Epoch 7/100
# 20001/20001 [==============================] - 1s 50us/step - loss: 6.6315e-04 - acc: 4.9997e-05
# Epoch 8/100
# 20001/20001 [==============================] - 1s 47us/step - loss: 6.4538e-04 - acc: 4.9997e-05
# Epoch 9/100
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import numpy as np

if __name__ == '__main__':
	print '1'
	df = pd.read_csv('training_data_jointsall.csv')
	print 'a'
	#df = df.cumsum()

	fig1 = plt.figure()
	#df.j1.plot()
	#df.j2.plot()
	#df.j3.plot()
	df.j2[0:500].plot()

	df.jd2[0:500].plot(); plt.legend(loc='best')
	fig2 = plt.figure(); df.e2[0:500].plot(lw=0.1,marker='.'); plt.legend(loc='best')
	new_data = df.j2 - df.jd2
	fig3 = plt.figure(); new_data.plot(lw=0.1,marker='.'); plt.legend(loc='best')
# Out:
# 1
# a
